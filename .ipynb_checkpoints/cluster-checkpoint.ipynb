# %% [markdown]
# 导入包

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline#引入正则化
from sklearn.preprocessing import StandardScaler#数据标准化 / 归一化的作用 提升模型精度
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
# Out:
# D:\Anaconda\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# D:\Anaconda\lib\site-packages\sklearn\linear_model\least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %% [markdown]
# 环形数据1生成

# %%
from sklearn import datasets
n_samples=300
X1,y1=datasets.make_circles(n_samples=n_samples,factor=.5,noise=.05)

# %% [markdown]
# 片形数据2生成

# %%
from sklearn import datasets
n_samples=300
X2,y2=datasets.make_blobs()

# %% [markdown]
# S形布局数据3生成

# %%
from sklearn import datasets
n_samples=300
X3,y3=datasets.make_s_curve()

# %% [markdown]
# Kmeans模型建立

# %%
from sklearn.cluster import KMeans
kmeans1=KMeans(n_clusters=2,random_state=0).fit(X1)
klabels1=kmeans1.labels_
kmeans2=KMeans(n_clusters=2,random_state=0).fit(X2)
klabels2=kmeans2.labels_
kmeans3=KMeans(n_clusters=2,random_state=0).fit(X3)
klabels3=kmeans3.labels_
# Out:
# D:\Anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# D:\Anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...

# %% [markdown]
# DBSCAN模型的建立

# %%
from sklearn.cluster import DBSCAN
Dbscan1=DBSCAN(eps=0.2,min_samples=2,metric='euclidean').fit(X1)
DBlabels1=Dbscan1.labels_
Dbscan2=DBSCAN(eps=0.2,min_samples=2,metric='euclidean').fit(X2)
DBlabels2=Dbscan2.labels_
Dbscan3=DBSCAN(eps=0.2,min_samples=2,metric='euclidean').fit(X3)
DBlabels3=Dbscan3.labels_

# %% [markdown]
# 调整兰德系数

# %%
print("kmearns1",metrics.adjusted_rand_score(y1,klabels1))
print("kmearns2",metrics.adjusted_rand_score(y2,klabels2))
print("kmearns3",metrics.adjusted_rand_score(y3,klabels3))
print("Dbscan1",metrics.adjusted_rand_score(y1,DBlabels1))
print("Dbscan2",metrics.adjusted_rand_score(y2,DBlabels2))
print("Dbscan3",metrics.adjusted_rand_score(y3,DBlabels3))
# Out:
# kmearns1 -0.0033551061267077698
# kmearns2 0.5737902531427588
# kmearns3 0.0
# Dbscan1 1.0
# Dbscan2 0.018275124274062537
# Dbscan3 0.0
# D:\Anaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:98: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)
# ...

# %%
print("kmearns1",metrics.homogeneity_score(y1,klabels1))
print("kmearns2",metrics.homogeneity_score(y2,klabels2))
print("kmearns3",metrics.homogeneity_score(y3,klabels3))
print("Dbscan1",metrics.homogeneity_score(y1,DBlabels1))
print("Dbscan2",metrics.homogeneity_score(y2,DBlabels2))
print("Dbscan3",metrics.homogeneity_score(y3,DBlabels3))
# Out:
# kmearns1 6.406853007629834e-16
# kmearns2 0.583548580081132
# kmearns3 0.14837994818372904
# Dbscan1 1.0
# Dbscan2 0.27907561584354695
# Dbscan3 0.49445674278630447
# D:\Anaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:98: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)
# ...

# %%
print("kmearns1",metrics.completeness_score(y1,klabels1))
print("kmearns2",metrics.completeness_score(y2,klabels2))
print("kmearns3",metrics.completeness_score(y3,klabels3))
print("Dbscan1",metrics.completeness_score(y1,DBlabels1))
print("Dbscan2",metrics.completeness_score(y2,DBlabels2))
print("Dbscan3",metrics.completeness_score(y3,DBlabels3))
# Out:
# kmearns1 6.40767474936404e-16
# kmearns2 0.9999999999999997
# kmearns3 1.0000000000000009
# Dbscan1 1.0
# Dbscan2 0.23340904424905845
# Dbscan3 0.9999999999999998
# D:\Anaconda\lib\site-packages\sklearn\metrics\cluster\supervised.py:98: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)
# ...
